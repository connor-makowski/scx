# %%
pip install scx>=1.2.0 #Note: This may throw an Error in Google Colab since Colab uses an outdated duckdb package. This file should still work in Colab without issues.
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <p class="MsoNormal">Food On Wheels has implemented a new strategy to reduce costs. All orders will be prepared in a central kitchen, sent to three distribution hubs in the city by motorbike and then delivered from the hubs to the city areas by bike. Motorbikes, just as bikes, can only deliver one box at a time.<o:p></o:p></p>
# <p><b>Table 3: Delivery time from central kitchen to distribution hubs (in minutes)</b></p>
# <table width="600" height="66" style="height: 76.8px;">
# <tbody>
# <tr style="height: 25.6px;">
# <td width="30%" style="text-align: center; border: 1px solid black; width: 20.2px; height: 25.6px;"></td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 91.212px; height: 25.6px;">Hub 1</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 91.212px; height: 25.6px;">Hub 2</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 91.975px; height: 25.6px;">Hub 3</td>
# </tr>
# <tr style="height: 51.2px;">
# <td width="30%" style="text-align: center; border: 1px solid black; width: 20.2px; height: 51.2px;">Central kitchen</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 91.212px; height: 51.2px;">2</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 91.212px; height: 51.2px;">5</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 91.975px; height: 51.2px;">7</td>
# </tr>
# </tbody>
# </table>
# <p><b></b></p>
# <p><b>Table 4: Delivery time from distribution hubs to city areas (in minutes)</b></p>
# <table width="447" height="186" style="width: 33.2692%;">
# <tbody>
# <tr>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;"></td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">Hub 1</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">Hub 2</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.8697%;">Hub 3</td>
# </tr>
# <tr>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">Area 1</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">13</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">15</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.8697%;">3</td>
# </tr>
# <tr>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">Area 2</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">7</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">4</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.8697%;">3</td>
# </tr>
# <tr>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">Area 3</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">14</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">10</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.8697%;">11</td>
# </tr>
# <tr>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">Area 4</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">14</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">8</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.8697%;">11</td>
# </tr>
# <tr>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">Area 5</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">5</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.6827%;">7</td>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 24.8697%;">10</td>
# </tr>
# </tbody>
# </table>
# <p></p>
# <p><b>Table 5: Distribution hubs' daily capacity (in boxes)</b></p>
# <table width="617" height="35" style="width: 33.1317%;">
# <tbody>
# <tr>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 15.465%;"></td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 27.9293%;">Hub 1</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 27.9293%;">Hub 2</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 27.9293%;">Hub 3</td>
# </tr>
# <tr>
# <td width="10%" style="text-align: center; border: 1px solid black; width: 15.465%;">Capacity</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 27.9293%;">150</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 27.9293%;">100</td>
# <td width="30%" style="text-align: center; border: 1px solid black; width: 27.9293%;">150</td>
# </tr>
# </tbody>
# </table>
# <p></p>
# <p><strong>Adjust your model to help them decide which areas to serve from each Hub to minimize total delivery time.</strong></p>
# <a href="https://youtu.be/IkWb56pAxxo">FOW P2 Video Walkthrough Link</a><br/>
# <iframe width="560" height="315"
#     src="https://www.youtube.com/embed/IkWb56pAxxo" frameborder="0" allowfullscreen>
# </iframe>

# %%
from scx.optimize import Model

# %%
transport = [
    # Central Kitchen to Hubs
    {
        'origin_name':'K1',
        'destination_name':'H1',
        'time': 2,
    },
    {
        'origin_name':'K1',
        'destination_name':'H2',
        'time': 5,
    },
    {
        'origin_name':'K1',
        'destination_name':'H3',
        'time': 7,
    },
    # Hubs to Areas
    {
        'origin_name':'H1',
        'destination_name':'A1',
        'time': 13,
    },
    {
        'origin_name':'H1',
        'destination_name':'A2',
        'time': 7,
    },
    {
        'origin_name':'H1',
        'destination_name':'A3',
        'time': 14,
    },
    {
        'origin_name':'H1',
        'destination_name':'A4',
        'time': 14,
    },
    {
        'origin_name':'H1',
        'destination_name':'A5',
        'time': 5,
    },
    {
        'origin_name':'H2',
        'destination_name':'A1',
        'time': 15,
    },
    {
        'origin_name':'H2',
        'destination_name':'A2',
        'time': 4,
    },
    {
        'origin_name':'H2',
        'destination_name':'A3',
        'time': 10,
    },
    {
        'origin_name':'H2',
        'destination_name':'A4',
        'time': 8,
    },
    {
        'origin_name':'H2',
        'destination_name':'A5',
        'time': 7,
    },
    {
        'origin_name':'H3',
        'destination_name':'A1',
        'time': 3,
    },
    {
        'origin_name':'H3',
        'destination_name':'A2',
        'time': 3,
    },
    {
        'origin_name':'H3',
        'destination_name':'A3',
        'time': 11,
    },
    {
        'origin_name':'H3',
        'destination_name':'A4',
        'time': 11,
    },
    {
        'origin_name':'H3',
        'destination_name':'A5',
        'time': 10,
    },

]

kitchens = [
    {
        'name': 'K1',
    },
]

hubs = [
    {
        'name': "H1",
        'limit': 150
    },
    {
        'name': "H2",
        'limit': 100
    },
    {
        'name': "H3",
        'limit': 150
    },
]

demand = [
    {
        'name':'A1',
        'demand':101
    },
    {
        'name':'A2',
        'demand':61
    },
    {
        'name':'A3',
        'demand':101
    },
    {
        'name':'A4',
        'demand':87
    },
    {
        'name':'A5',
        'demand':50
    },
]

# %%
for t in transport:
    # Create decision variables for each item in transport
    t['amt']=Model.variable(name=f"{t['origin_name']}__{t['destination_name']}__amt", lowBound=0)

# %%
# Initialize the model
my_model = Model(name="FoW", sense='minimize')


# Add the Objective Fn
my_model.add_objective(
    fn=Model.sum([t['amt']*t['time'] for t in transport])
)

# Add Constraints
## Demand Constraint
for d in demand:
    my_model.add_constraint(
        name=f"{d['name']}__demand",
        fn=Model.sum([t['amt'] for t in transport if t['destination_name']==d['name']]) >= d['demand']
    )

## Hub Constraints
for h in hubs:
    ## Hub Capacity Constraint
    my_model.add_constraint(
        name=f"{h['name']}__capacity",
        fn=Model.sum([t['amt'] for t in transport if t['origin_name']==h['name']]) <= h['limit']
    )

    ## Conservation of Flow Constraint
    my_model.add_constraint(
        name=f"{h['name']}__conservation_of_flow",
        # Set inbound flows for the hub equal to outbound flows
        fn=Model.sum(
            [t['amt'] for t in transport if t['destination_name']==h['name']]
        ) == Model.sum(
            [t['amt'] for t in transport if t['origin_name']==h['name']]
        )
    )

# Solve the model
my_model.solve()

# %%
my_model.show_formulation()
# Out:
# FoW:
# MINIMIZE
# 13*H1__A1__amt + 7*H1__A2__amt + 14*H1__A3__amt + 14*H1__A4__amt + 5*H1__A5__amt + 15*H2__A1__amt + 4*H2__A2__amt + 10*H2__A3__amt + 8*H2__A4__amt + 7*H2__A5__amt + 3*H3__A1__amt + 3*H3__A2__amt + 11*H3__A3__amt + 11*H3__A4__amt + 10*H3__A5__amt + 2*K1__H1__amt + 5*K1__H2__amt + 7*K1__H3__amt + 0
# SUBJECT TO
# A1__demand: H1__A1__amt + H2__A1__amt + H3__A1__amt >= 101
#
# A2__demand: H1__A2__amt + H2__A2__amt + H3__A2__amt >= 61
#
# A3__demand: H1__A3__amt + H2__A3__amt + H3__A3__amt >= 101
#
# A4__demand: H1__A4__amt + H2__A4__amt + H3__A4__amt >= 87
#
# A5__demand: H1__A5__amt + H2__A5__amt + H3__A5__amt >= 50
#
# H1__capacity: H1__A1__amt + H1__A2__amt + H1__A3__amt + H1__A4__amt
#  + H1__A5__amt <= 150
#
# H1__conservation_of_flow: - H1__A1__amt - H1__A2__amt - H1__A3__amt
#  - H1__A4__amt - H1__A5__amt + K1__H1__amt = 0
#
# H2__capacity: H2__A1__amt + H2__A2__amt + H2__A3__amt + H2__A4__amt
#  + H2__A5__amt <= 100
#
# ...

# %%
# Show the outputs
my_model.show_outputs()
# Out:
# {'objective': 4692.0,
#  'status': 'Optimal',
#  'variables': {'H1__A1__amt': 0.0,
#                'H1__A2__amt': 12.0,
#                'H1__A3__amt': 88.0,
#                'H1__A4__amt': 0.0,
#                'H1__A5__amt': 50.0,
#                'H2__A1__amt': 0.0,
#                'H2__A2__amt': 0.0,
#                'H2__A3__amt': 13.0,
#                'H2__A4__amt': 87.0,
#                'H2__A5__amt': 0.0,
#                'H3__A1__amt': 101.0,
#                'H3__A2__amt': 49.0,
#                'H3__A3__amt': 0.0,
#                'H3__A4__amt': 0.0,
#                'H3__A5__amt': 0.0,
#                'K1__H1__amt': 150.0,
#                'K1__H2__amt': 100.0,
#                'K1__H3__amt': 150.0}}
